# %%
import pandas as pd

from elder_care.config import SRC

# %%
wave = 1
module = "hc"
path_to_raw_data = SRC / f"data/sharew{wave}/sharew{wave}_rel8-0-0_{module}.dta"
dat = pd.read_stata(path_to_raw_data, convert_categoricals=False)

# %%
dat["hc029_"]
# Out:
# 0        5.0
# 1        5.0
# 2        5.0
# 3        5.0
# 4        5.0
#         ...
# 30414    5.0
# 30415    5.0
# 30416    5.0
# 30417    5.0
# 30418    5.0
# Name: hc029_, Length: 30419, dtype: float64

# %%
dat["hc696_"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/elder_care/lib/python3.10/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hc696_'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 dat["hc696_"]
#
# ...

# %%
list(dat)
# Out:
# ['mergeid',
#  'hhid1',
#  'mergeidp1',
#  'coupleid1',
#  'country',
#  'language',
#  'exrate',
#  'hc002_',
#  'hc003_',
#  'hc004_',
#  'hc005_',
#  'hc006_',
#  'hc007_',
#  'hc008_',
#  'hc009_',
#  'hc010_',
#  'hc011_',
#  'hc012_',
#  'hc013_',
#  'hc014_',
#  'hc015d1',
#  'hc015d2',
#  'hc015d3',
#  'hc016_',
#  'hc017_',
#  'hc018_',
#  'hc019_',
#  'hc020_',
#  'hc021_',
#  'hc022_',
#  'hc023_',
#  'hc024_',
#  'hc025_',
#  'hc026_',
#  'hc027_',
#  'hc028_',
#  'hc029_',
#  'hc030_',
#  'hc031_',
#  'hc032d1',
#  'hc032d2',
#  'hc032d3',
#  'hc032dno',
#  'hc033_',
#  'hc034_',
#  'hc035_',
#  'hc036_',
#  'hc037_',
#  'hc038_',
#  'hc039d1',
#  'hc039d2',
#  'hc039d3',
#  'hc039d4',
#  'hc039d5',
#  'hc039d6',
#  'hc039d7',
#  'hc039d8',
#  'hc039d9',
#  'hc039d10',
#  'hc039d11',
#  'hc039dot',
#  'hc040_',
#  'hc041d1',
#  'hc041d2',
#  'hc041d3',
#  'hc041d4',
#  'hc041d5',
#  'hc041d6',
#  'hc041d7',
#  'hc041d8',
#  'hc041d9',
#  'hc041d10',
#  'hc041d11',
# ...

# %%
wave = 8
module = "gv_children"
path_to_raw_data = SRC / f"data/sharew{wave}/sharew{wave}_rel8-0-0_{module}.dta"
dat = pd.read_stata(path_to_raw_data, convert_categoricals=False)

# %%
list(dat)
# Out:
# ['mergeid',
#  'hhid8',
#  'mergeidp8',
#  'coupleid8',
#  'country',
#  'language',
#  'ch001_',
#  'ch_gender_1',
#  'ch_gender_2',
#  'ch_gender_3',
#  'ch_gender_4',
#  'ch_gender_5',
#  'ch_gender_6',
#  'ch_gender_7',
#  'ch_gender_8',
#  'ch_gender_9',
#  'ch_gender_10',
#  'ch_gender_11',
#  'ch_gender_12',
#  'ch_gender_13',
#  'ch_gender_14',
#  'ch_gender_15',
#  'ch_gender_16',
#  'ch_gender_17',
#  'ch_gender_18',
#  'ch_gender_19',
#  'ch_gender_20',
#  'ch_yrbirth_1',
#  'ch_yrbirth_2',
#  'ch_yrbirth_3',
#  'ch_yrbirth_4',
#  'ch_yrbirth_5',
#  'ch_yrbirth_6',
#  'ch_yrbirth_7',
#  'ch_yrbirth_8',
#  'ch_yrbirth_9',
#  'ch_yrbirth_10',
#  'ch_yrbirth_11',
#  'ch_yrbirth_12',
#  'ch_yrbirth_13',
#  'ch_yrbirth_14',
#  'ch_yrbirth_15',
#  'ch_yrbirth_16',
#  'ch_yrbirth_17',
#  'ch_yrbirth_18',
#  'ch_yrbirth_19',
#  'ch_yrbirth_20',
#  'ch_relation_1',
#  'ch_relation_2',
#  'ch_relation_3',
#  'ch_relation_4',
#  'ch_relation_5',
#  'ch_relation_6',
# ...

# %%
dat.head()
# Out:
#         mergeid        hhid8     mergeidp8        coupleid8  country  \
# 0  AT-001215-01  AT-001215-A                                      11
# 1  AT-001492-01  AT-001492-A  AT-001492-02  AT-001492-01-02       11
# 2  AT-001492-02  AT-001492-A  AT-001492-01  AT-001492-01-02       11
# 3  AT-001881-01  AT-001881-A                                      11
# 4  AT-001881-02  AT-001881-B                                      11
#
#    language  ch001_  ch_gender_1  ch_gender_2  ch_gender_3  ...  \
# 0        11     0.0          NaN          NaN          NaN  ...
# 1        11     6.0          2.0          2.0          2.0  ...
# 2        11     NaN          NaN          NaN          NaN  ...
# 3        11     3.0          1.0          1.0          2.0  ...
# 4        11     2.0          1.0          NaN          NaN  ...
#
#    ch_further_education_20_13  ch_further_education_20_14  \
# 0                         NaN                         NaN
# ...

# %%
wave = 8
module = "gv_imputations"
path_to_raw_data = SRC / f"data/sharew{wave}/sharew{wave}_rel8-0-0_{module}.dta"
dat = pd.read_stata(path_to_raw_data, convert_categoricals=False)

# %%
dat.head(20)
# Out:
#          mergeid        hhid8     mergeidp8        coupleid8  country  \
# 0   AT-001215-01  AT-001215-A                                      11
# 1   AT-001215-01  AT-001215-A                                      11
# 2   AT-001215-01  AT-001215-A                                      11
# 3   AT-001215-01  AT-001215-A                                      11
# 4   AT-001215-01  AT-001215-A                                      11
# 5   AT-001492-01  AT-001492-A  AT-001492-02  AT-001492-01-02       11
# 6   AT-001492-01  AT-001492-A  AT-001492-02  AT-001492-01-02       11
# 7   AT-001492-01  AT-001492-A  AT-001492-02  AT-001492-01-02       11
# 8   AT-001492-01  AT-001492-A  AT-001492-02  AT-001492-01-02       11
# 9   AT-001492-01  AT-001492-A  AT-001492-02  AT-001492-01-02       11
# 10  AT-001492-02  AT-001492-A  AT-001492-01  AT-001492-01-02       11
# 11  AT-001492-02  AT-001492-A  AT-001492-01  AT-001492-01-02       11
# ...
